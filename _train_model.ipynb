# %% [markdown]
# # Comparing methods of hurricane forecast uncertainty
# ##### author: Elizabeth A. Barnes, Randal J. Barnes and Mark DeMaria

# %%
import datetime
import os
import pickle
import pprint
import time

import experiment_settings
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from build_data import build_hurricane_data
import build_model
from model_diagnostics import plot_history
from save_model_run import save_model_run
from sklearn import preprocessing
from training_instrumentation import TrainingInstrumentation
from silence_tensorflow import silence_tensorflow
import tensorflow_probability as tfp
import random
import imp

silence_tensorflow()

tf.config.set_visible_devices([], 'GPU') # turn-off tensorflow-metal if it is on

# %%
__author__ = "Randal J Barnes and Elizabeth A. Barnes"
__version__ = "v1.0.1, 27 July 2022"

imp.reload(experiment_settings)
EXP_NAME_LIST = (
    # "longitude202_AL48",
    # "latitude202_AL48",
    "longitude301_EPCP48",
    "latitude301_EPCP48",

)

OVERWRITE_MODEL = False
DATA_PATH = "data/"
MODEL_PATH = "saved_models/"

# %%
mpl.rcParams["figure.facecolor"] = "white"
mpl.rcParams["figure.dpi"] = 150
np.warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %% [markdown]
# ## Start looping through runs

# %%
imp.reload(build_model)

for exp_name in EXP_NAME_LIST:
    settings = experiment_settings.get_settings(exp_name)

    # set testing data
    if settings["test_condition"] == "leave-one-out":
        TESTING_YEARS_LIST = (2020,)#np.arange(2013,2022)
    elif settings["test_condition"] == "years":
        TESTING_YEARS_LIST = (np.copy(settings["years_test"]))
    else:
        raise NotImplementError('no such testing condition')

        
        
    for testing_years in TESTING_YEARS_LIST:        
        # set testing year
        settings["years_test"] = (testing_years,)
        
        
        for rng_seed in settings['rng_seed_list']:
            settings['rng_seed'] = rng_seed

            # build the intensity data tensors
            (
                data_summary,        
                x_train,
                onehot_train,
                x_val,
                onehot_val,
                x_test,
                onehot_test,        
                x_valtest,
                onehot_valtest,
                df_train,
                df_val,
                df_test,
                df_valtest,
            ) = build_hurricane_data(DATA_PATH, settings, verbose=1)

            # define the callbacks
            earlystoping_callback = tf.keras.callbacks.EarlyStopping(
                monitor="val_loss",
                mode="min",
                patience=settings["patience"],
                restore_best_weights=True,
                verbose=1,
            )

            training_callback = TrainingInstrumentation(
                x_train,
                onehot_train,
                interval=50,
            )

            callbacks = [earlystoping_callback, 
                         # training_callback,
                        ]

            # set network seed and train the model
            NETWORK_SEED_LIST = [settings["rng_seed"]]

            for network_seed in NETWORK_SEED_LIST:
                
                # set random seeds
                np.random.seed(rng_seed)
                random.seed(rng_seed)                            
                tf.random.set_seed(network_seed) 

                # Create the model name.
                model_name = (
                    exp_name + "_" + 
                    str(testing_years) + '_' +
                    settings["uncertainty_type"] + '_' + 
                    f"network_seed_{network_seed}_rng_seed_{settings['rng_seed']}"
                )
                pprint.pprint(model_name)

                # Make, compile, and train the model
                tf.keras.backend.clear_session()            
                model = build_model.make_model(
                    settings,
                    x_train,
                    onehot_train,
                    model_compile=True,
                )   
                model.summary()

                # check if the model exists
                model_savename = MODEL_PATH + model_name + "_weights.h5"
                if os.path.exists(model_savename) and OVERWRITE_MODEL==False:
                    print(model_savename + 'exists. Skipping...')
                    continue

                # train the network
                start_time = time.time()
                history = model.fit(
                    x_train,
                    onehot_train,
                    validation_data=(x_val, onehot_val),
                    batch_size=settings["batch_size"],
                    epochs=settings["n_epochs"],
                    shuffle=True,
                    verbose=0,
                    callbacks=callbacks,
                )
                stop_time = time.time()

                # Display the results, and save the model rum.
                best_epoch = np.argmin(history.history["val_loss"])
                fit_summary = {
                    "network_seed": network_seed,
                    "elapsed_time": stop_time - start_time,
                    "best_epoch": best_epoch,
                    "loss_train": history.history["loss"][best_epoch],
                    "loss_valid": history.history["val_loss"][best_epoch],
                }
                pprint.pprint(fit_summary, width=80)
                plot_history(history, model_name)

                save_model_run(
                    data_summary,
                    fit_summary,
                    model,
                    MODEL_PATH,
                    model_name,
                    settings,
                    __version__,
                )
# Out:
# years(2020,) withheld for testing
# {'datafile_path': 'data/nnfit_vlist_02-Jun-2022.dat',
#  'onehot_test_shape': (123, 3),
#  'onehot_train_shape': (1860, 3),
#  'onehot_val_shape': (200, 3),
#  'x_names': ['NCT',
#              'VMAX0',
#              'AVDX',
#              'EMDX',
#              'EGDX',
#              'HWDX',
#              'LONC',
#              'LATC',
#              'VMXC',
#              'DV12',
#              'SLAT',
#              'SHDC',
#              'SSTN',
#              'DTL'],
#  'x_test_shape': (123, 14),
#  'x_train_shape': (1860, 14),
#  'x_val_shape': (200, 14),
#  'y_name': ['OBDX']}
# 'longitude301_EPCP48_2020_shash3_network_seed_222_rng_seed_222'
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 14)]         0           []
#
#  normalization (Normalization)  (None, 14)           29          ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 14)           0           ['normalization[0][0]']
#
#  dense (Dense)                  (None, 15)           225         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 15)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 10)           160         ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 10)           0           ['dense_1[0][0]']
#
#  log_sigma_z_unit (Dense)       (None, 1)            11          ['dropout_2[0][0]']
#
#  mu_z_unit (Dense)              (None, 1)            11          ['dropout_2[0][0]']
#
#  log_sigma_unit (Rescaling)     (None, 1)            0           ['log_sigma_z_unit[0][0]']
#
#  mu_unit (Rescaling)            (None, 1)            0           ['mu_z_unit[0][0]']
#
#  sigma_unit (Exponentiate)      (None, 1)            0           ['log_sigma_unit[0][0]']
#
#  gamma_unit (Dense)             (None, 1)            11          ['dropout_2[0][0]']
#
#  concatenate (Concatenate)      (None, 3)            0           ['mu_unit[0][0]',
#                                                                   'sigma_unit[0][0]',
#                                                                   'gamma_unit[0][0]']
#
# ==================================================================================================
# Total params: 447
# Trainable params: 418
# Non-trainable params: 29
# __________________________________________________________________________________________________
# Restoring model weights from the end of the best epoch: 693.
# Epoch 00943: early stopping
# {'best_epoch': 692,
#  'elapsed_time': 23.19659996032715,
#  'loss_train': 5.647737503051758,
#  'loss_valid': 5.846218109130859,
#  'network_seed': 222}
# years(2020,) withheld for testing
# {'datafile_path': 'data/nnfit_vlist_02-Jun-2022.dat',
#  'onehot_test_shape': (123, 3),
#  'onehot_train_shape': (1860, 3),
#  'onehot_val_shape': (200, 3),
#  'x_names': ['NCT',
#              'VMAX0',
#              'AVDX',
#              'EMDX',
#              'EGDX',
#              'HWDX',
#              'LONC',
#              'LATC',
#              'VMXC',
#              'DV12',
#              'SLAT',
#              'SHDC',
#              'SSTN',
#              'DTL'],
#  'x_test_shape': (123, 14),
#  'x_train_shape': (1860, 14),
#  'x_val_shape': (200, 14),
#  'y_name': ['OBDX']}
# 'longitude301_EPCP48_2020_shash3_network_seed_333_rng_seed_333'
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 14)]         0           []
#
#  normalization (Normalization)  (None, 14)           29          ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 14)           0           ['normalization[0][0]']
#
#  dense (Dense)                  (None, 15)           225         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 15)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 10)           160         ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 10)           0           ['dense_1[0][0]']
#
#  log_sigma_z_unit (Dense)       (None, 1)            11          ['dropout_2[0][0]']
#
#  mu_z_unit (Dense)              (None, 1)            11          ['dropout_2[0][0]']
#
#  log_sigma_unit (Rescaling)     (None, 1)            0           ['log_sigma_z_unit[0][0]']
#
#  mu_unit (Rescaling)            (None, 1)            0           ['mu_z_unit[0][0]']
#
#  sigma_unit (Exponentiate)      (None, 1)            0           ['log_sigma_unit[0][0]']
#
#  gamma_unit (Dense)             (None, 1)            11          ['dropout_2[0][0]']
#
#  concatenate (Concatenate)      (None, 3)            0           ['mu_unit[0][0]',
#                                                                   'sigma_unit[0][0]',
#                                                                   'gamma_unit[0][0]']
#
# ==================================================================================================
# Total params: 447
# Trainable params: 418
# Non-trainable params: 29
# __________________________________________________________________________________________________
# Restoring model weights from the end of the best epoch: 275.
# Epoch 00525: early stopping
# {'best_epoch': 274,
#  'elapsed_time': 13.183640241622925,
#  'loss_train': 5.7656025886535645,
#  'loss_valid': 5.810651779174805,
#  'network_seed': 333}
# years(2020,) withheld for testing
# {'datafile_path': 'data/nnfit_vlist_02-Jun-2022.dat',
#  'onehot_test_shape': (123, 3),
#  'onehot_train_shape': (1860, 3),
#  'onehot_val_shape': (200, 3),
#  'x_names': ['NCT',
#              'VMAX0',
#              'AVDX',
#              'EMDX',
#              'EGDX',
#              'HWDX',
#              'LONC',
#              'LATC',
#              'VMXC',
#              'DV12',
#              'SLAT',
#              'SHDC',
#              'SSTN',
#              'DTL'],
#  'x_test_shape': (123, 14),
#  'x_train_shape': (1860, 14),
#  'x_val_shape': (200, 14),
#  'y_name': ['OBDX']}
# 'longitude301_EPCP48_2020_shash3_network_seed_416_rng_seed_416'
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 14)]         0           []
#
#  normalization (Normalization)  (None, 14)           29          ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 14)           0           ['normalization[0][0]']
#
#  dense (Dense)                  (None, 15)           225         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 15)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 10)           160         ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 10)           0           ['dense_1[0][0]']
#
#  log_sigma_z_unit (Dense)       (None, 1)            11          ['dropout_2[0][0]']
#
#  mu_z_unit (Dense)              (None, 1)            11          ['dropout_2[0][0]']
#
#  log_sigma_unit (Rescaling)     (None, 1)            0           ['log_sigma_z_unit[0][0]']
#
#  mu_unit (Rescaling)            (None, 1)            0           ['mu_z_unit[0][0]']
#
#  sigma_unit (Exponentiate)      (None, 1)            0           ['log_sigma_unit[0][0]']
#
#  gamma_unit (Dense)             (None, 1)            11          ['dropout_2[0][0]']
#
#  concatenate (Concatenate)      (None, 3)            0           ['mu_unit[0][0]',
#                                                                   'sigma_unit[0][0]',
#                                                                   'gamma_unit[0][0]']
#
# ==================================================================================================
# Total params: 447
# Trainable params: 418
# Non-trainable params: 29
# __________________________________________________________________________________________________
# Restoring model weights from the end of the best epoch: 53.
# Epoch 00303: early stopping
# {'best_epoch': 52,
#  'elapsed_time': 7.716521978378296,
#  'loss_train': 5.832543849945068,
#  'loss_valid': 5.879828453063965,
#  'network_seed': 416}
# years(2020,) withheld for testing
# {'datafile_path': 'data/nnfit_vlist_02-Jun-2022.dat',
#  'onehot_test_shape': (123, 3),
#  'onehot_train_shape': (1860, 3),
#  'onehot_val_shape': (200, 3),
#  'x_names': ['NCT',
#              'VMAX0',
#              'AVDX',
#              'EMDX',
#              'EGDX',
#              'HWDX',
#              'LONC',
#              'LATC',
#              'VMXC',
#              'DV12',
#              'SLAT',
#              'SHDC',
#              'SSTN',
#              'DTL'],
#  'x_test_shape': (123, 14),
#  'x_train_shape': (1860, 14),
#  'x_val_shape': (200, 14),
#  'y_name': ['OBDX']}
# 'longitude301_EPCP48_2020_shash3_network_seed_599_rng_seed_599'
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 14)]         0           []
#
#  normalization (Normalization)  (None, 14)           29          ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 14)           0           ['normalization[0][0]']
#
#  dense (Dense)                  (None, 15)           225         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 15)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 10)           160         ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 10)           0           ['dense_1[0][0]']
#
#  log_sigma_z_unit (Dense)       (None, 1)            11          ['dropout_2[0][0]']
#
#  mu_z_unit (Dense)              (None, 1)            11          ['dropout_2[0][0]']
#
#  log_sigma_unit (Rescaling)     (None, 1)            0           ['log_sigma_z_unit[0][0]']
#
#  mu_unit (Rescaling)            (None, 1)            0           ['mu_z_unit[0][0]']
#
#  sigma_unit (Exponentiate)      (None, 1)            0           ['log_sigma_unit[0][0]']
#
#  gamma_unit (Dense)             (None, 1)            11          ['dropout_2[0][0]']
#
#  concatenate (Concatenate)      (None, 3)            0           ['mu_unit[0][0]',
#                                                                   'sigma_unit[0][0]',
#                                                                   'gamma_unit[0][0]']
#
# ==================================================================================================
# Total params: 447
# Trainable params: 418
# Non-trainable params: 29
# __________________________________________________________________________________________________
# Restoring model weights from the end of the best epoch: 906.
# Epoch 01156: early stopping
# {'best_epoch': 905,
#  'elapsed_time': 27.840593814849854,
#  'loss_train': 5.6076483726501465,
#  'loss_valid': 5.653036117553711,
#  'network_seed': 599}
# years(2020,) withheld for testing
# {'datafile_path': 'data/nnfit_vlist_02-Jun-2022.dat',
#  'onehot_test_shape': (123, 3),
#  'onehot_train_shape': (1860, 3),
#  'onehot_val_shape': (200, 3),
#  'x_names': ['NCT',
#              'VMAX0',
#              'AVDX',
#              'EMDX',
#              'EGDX',
#              'HWDX',
#              'LONC',
#              'LATC',
#              'VMXC',
#              'DV12',
#              'SLAT',
#              'SHDC',
#              'SSTN',
#              'DTL'],
#  'x_test_shape': (123, 14),
#  'x_train_shape': (1860, 14),
#  'x_val_shape': (200, 14),
#  'y_name': ['OBDX']}
# 'longitude301_EPCP48_2020_shash3_network_seed_739_rng_seed_739'
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 14)]         0           []
#
#  normalization (Normalization)  (None, 14)           29          ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 14)           0           ['normalization[0][0]']
#
#  dense (Dense)                  (None, 15)           225         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 15)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 10)           160         ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 10)           0           ['dense_1[0][0]']
#
#  log_sigma_z_unit (Dense)       (None, 1)            11          ['dropout_2[0][0]']
#
#  mu_z_unit (Dense)              (None, 1)            11          ['dropout_2[0][0]']
#
#  log_sigma_unit (Rescaling)     (None, 1)            0           ['log_sigma_z_unit[0][0]']
#
#  mu_unit (Rescaling)            (None, 1)            0           ['mu_z_unit[0][0]']
#
#  sigma_unit (Exponentiate)      (None, 1)            0           ['log_sigma_unit[0][0]']
#
#  gamma_unit (Dense)             (None, 1)            11          ['dropout_2[0][0]']
#
#  concatenate (Concatenate)      (None, 3)            0           ['mu_unit[0][0]',
#                                                                   'sigma_unit[0][0]',
#                                                                   'gamma_unit[0][0]']
#
# ==================================================================================================
# Total params: 447
# Trainable params: 418
# Non-trainable params: 29
# __________________________________________________________________________________________________
# Restoring model weights from the end of the best epoch: 1943.
# Epoch 02193: early stopping
# {'best_epoch': 1942,
#  'elapsed_time': 52.18025016784668,
#  'loss_train': 5.5397725105285645,
#  'loss_valid': 5.682542324066162,
#  'network_seed': 739}
# years(2020,) withheld for testing
# {'datafile_path': 'data/nnfit_vlist_02-Jun-2022.dat',
#  'onehot_test_shape': (123, 3),
#  'onehot_train_shape': (1860, 3),
#  'onehot_val_shape': (200, 3),
#  'x_names': ['NCT',
#              'VMAX0',
#              'AVDY',
#              'EMDY',
#              'EGDY',
#              'HWDY',
#              'LONC',
#              'LATC',
#              'VMXC',
#              'DV12',
#              'SLAT',
#              'SHDC',
#              'SSTN',
#              'DTL'],
#  'x_test_shape': (123, 14),
#  'x_train_shape': (1860, 14),
#  'x_val_shape': (200, 14),
#  'y_name': ['OBDY']}
# 'latitude301_EPCP48_2020_shash3_network_seed_222_rng_seed_222'
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 14)]         0           []
#
#  normalization (Normalization)  (None, 14)           29          ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 14)           0           ['normalization[0][0]']
#
#  dense (Dense)                  (None, 15)           225         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 15)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 10)           160         ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 10)           0           ['dense_1[0][0]']
#
#  log_sigma_z_unit (Dense)       (None, 1)            11          ['dropout_2[0][0]']
#
#  mu_z_unit (Dense)              (None, 1)            11          ['dropout_2[0][0]']
#
#  log_sigma_unit (Rescaling)     (None, 1)            0           ['log_sigma_z_unit[0][0]']
#
#  mu_unit (Rescaling)            (None, 1)            0           ['mu_z_unit[0][0]']
#
#  sigma_unit (Exponentiate)      (None, 1)            0           ['log_sigma_unit[0][0]']
#
#  gamma_unit (Dense)             (None, 1)            11          ['dropout_2[0][0]']
#
#  concatenate (Concatenate)      (None, 3)            0           ['mu_unit[0][0]',
#                                                                   'sigma_unit[0][0]',
#                                                                   'gamma_unit[0][0]']
#
# ==================================================================================================
# Total params: 447
# Trainable params: 418
# Non-trainable params: 29
# __________________________________________________________________________________________________
# Restoring model weights from the end of the best epoch: 682.
# Epoch 00932: early stopping
# {'best_epoch': 681,
#  'elapsed_time': 22.664777994155884,
#  'loss_train': 5.552881717681885,
#  'loss_valid': 5.7299017906188965,
#  'network_seed': 222}
# years(2020,) withheld for testing
# {'datafile_path': 'data/nnfit_vlist_02-Jun-2022.dat',
#  'onehot_test_shape': (123, 3),
#  'onehot_train_shape': (1860, 3),
#  'onehot_val_shape': (200, 3),
#  'x_names': ['NCT',
#              'VMAX0',
#              'AVDY',
#              'EMDY',
#              'EGDY',
#              'HWDY',
#              'LONC',
#              'LATC',
#              'VMXC',
#              'DV12',
#              'SLAT',
#              'SHDC',
#              'SSTN',
#              'DTL'],
#  'x_test_shape': (123, 14),
#  'x_train_shape': (1860, 14),
#  'x_val_shape': (200, 14),
#  'y_name': ['OBDY']}
# 'latitude301_EPCP48_2020_shash3_network_seed_333_rng_seed_333'
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 14)]         0           []
#
#  normalization (Normalization)  (None, 14)           29          ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 14)           0           ['normalization[0][0]']
#
#  dense (Dense)                  (None, 15)           225         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 15)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 10)           160         ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 10)           0           ['dense_1[0][0]']
#
#  log_sigma_z_unit (Dense)       (None, 1)            11          ['dropout_2[0][0]']
#
#  mu_z_unit (Dense)              (None, 1)            11          ['dropout_2[0][0]']
#
#  log_sigma_unit (Rescaling)     (None, 1)            0           ['log_sigma_z_unit[0][0]']
#
#  mu_unit (Rescaling)            (None, 1)            0           ['mu_z_unit[0][0]']
#
#  sigma_unit (Exponentiate)      (None, 1)            0           ['log_sigma_unit[0][0]']
#
#  gamma_unit (Dense)             (None, 1)            11          ['dropout_2[0][0]']
#
#  concatenate (Concatenate)      (None, 3)            0           ['mu_unit[0][0]',
#                                                                   'sigma_unit[0][0]',
#                                                                   'gamma_unit[0][0]']
#
# ==================================================================================================
# Total params: 447
# Trainable params: 418
# Non-trainable params: 29
# __________________________________________________________________________________________________
# Restoring model weights from the end of the best epoch: 512.
# Epoch 00762: early stopping
# {'best_epoch': 511,
#  'elapsed_time': 18.600430011749268,
#  'loss_train': 5.570154666900635,
#  'loss_valid': 5.652672290802002,
#  'network_seed': 333}
# years(2020,) withheld for testing
# {'datafile_path': 'data/nnfit_vlist_02-Jun-2022.dat',
#  'onehot_test_shape': (123, 3),
#  'onehot_train_shape': (1860, 3),
#  'onehot_val_shape': (200, 3),
#  'x_names': ['NCT',
#              'VMAX0',
#              'AVDY',
#              'EMDY',
#              'EGDY',
#              'HWDY',
#              'LONC',
#              'LATC',
#              'VMXC',
#              'DV12',
#              'SLAT',
#              'SHDC',
#              'SSTN',
#              'DTL'],
#  'x_test_shape': (123, 14),
#  'x_train_shape': (1860, 14),
#  'x_val_shape': (200, 14),
#  'y_name': ['OBDY']}
# 'latitude301_EPCP48_2020_shash3_network_seed_416_rng_seed_416'
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 14)]         0           []
#
#  normalization (Normalization)  (None, 14)           29          ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 14)           0           ['normalization[0][0]']
#
#  dense (Dense)                  (None, 15)           225         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 15)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 10)           160         ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 10)           0           ['dense_1[0][0]']
#
#  log_sigma_z_unit (Dense)       (None, 1)            11          ['dropout_2[0][0]']
#
#  mu_z_unit (Dense)              (None, 1)            11          ['dropout_2[0][0]']
#
#  log_sigma_unit (Rescaling)     (None, 1)            0           ['log_sigma_z_unit[0][0]']
#
#  mu_unit (Rescaling)            (None, 1)            0           ['mu_z_unit[0][0]']
#
#  sigma_unit (Exponentiate)      (None, 1)            0           ['log_sigma_unit[0][0]']
#
#  gamma_unit (Dense)             (None, 1)            11          ['dropout_2[0][0]']
#
#  concatenate (Concatenate)      (None, 3)            0           ['mu_unit[0][0]',
#                                                                   'sigma_unit[0][0]',
#                                                                   'gamma_unit[0][0]']
#
# ==================================================================================================
# Total params: 447
# Trainable params: 418
# Non-trainable params: 29
# __________________________________________________________________________________________________
# Restoring model weights from the end of the best epoch: 549.
# Epoch 00799: early stopping
# {'best_epoch': 548,
#  'elapsed_time': 19.333107233047485,
#  'loss_train': 5.554458141326904,
#  'loss_valid': 5.723320484161377,
#  'network_seed': 416}
# years(2020,) withheld for testing
# {'datafile_path': 'data/nnfit_vlist_02-Jun-2022.dat',
#  'onehot_test_shape': (123, 3),
#  'onehot_train_shape': (1860, 3),
#  'onehot_val_shape': (200, 3),
#  'x_names': ['NCT',
#              'VMAX0',
#              'AVDY',
#              'EMDY',
#              'EGDY',
#              'HWDY',
#              'LONC',
#              'LATC',
#              'VMXC',
#              'DV12',
#              'SLAT',
#              'SHDC',
#              'SSTN',
#              'DTL'],
#  'x_test_shape': (123, 14),
#  'x_train_shape': (1860, 14),
#  'x_val_shape': (200, 14),
#  'y_name': ['OBDY']}
# 'latitude301_EPCP48_2020_shash3_network_seed_599_rng_seed_599'
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 14)]         0           []
#
#  normalization (Normalization)  (None, 14)           29          ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 14)           0           ['normalization[0][0]']
#
#  dense (Dense)                  (None, 15)           225         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 15)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 10)           160         ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 10)           0           ['dense_1[0][0]']
#
#  log_sigma_z_unit (Dense)       (None, 1)            11          ['dropout_2[0][0]']
#
#  mu_z_unit (Dense)              (None, 1)            11          ['dropout_2[0][0]']
#
#  log_sigma_unit (Rescaling)     (None, 1)            0           ['log_sigma_z_unit[0][0]']
#
#  mu_unit (Rescaling)            (None, 1)            0           ['mu_z_unit[0][0]']
#
#  sigma_unit (Exponentiate)      (None, 1)            0           ['log_sigma_unit[0][0]']
#
#  gamma_unit (Dense)             (None, 1)            11          ['dropout_2[0][0]']
#
#  concatenate (Concatenate)      (None, 3)            0           ['mu_unit[0][0]',
#                                                                   'sigma_unit[0][0]',
#                                                                   'gamma_unit[0][0]']
#
# ==================================================================================================
# Total params: 447
# Trainable params: 418
# Non-trainable params: 29
# __________________________________________________________________________________________________
# Restoring model weights from the end of the best epoch: 959.
# Epoch 01209: early stopping
# {'best_epoch': 958,
#  'elapsed_time': 29.81511688232422,
#  'loss_train': 5.524514198303223,
#  'loss_valid': 5.608677864074707,
#  'network_seed': 599}
# years(2020,) withheld for testing
# {'datafile_path': 'data/nnfit_vlist_02-Jun-2022.dat',
#  'onehot_test_shape': (123, 3),
#  'onehot_train_shape': (1860, 3),
#  'onehot_val_shape': (200, 3),
#  'x_names': ['NCT',
#              'VMAX0',
#              'AVDY',
#              'EMDY',
#              'EGDY',
#              'HWDY',
#              'LONC',
#              'LATC',
#              'VMXC',
#              'DV12',
#              'SLAT',
#              'SHDC',
#              'SSTN',
#              'DTL'],
#  'x_test_shape': (123, 14),
#  'x_train_shape': (1860, 14),
#  'x_val_shape': (200, 14),
#  'y_name': ['OBDY']}
# 'latitude301_EPCP48_2020_shash3_network_seed_739_rng_seed_739'
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 14)]         0           []
#
#  normalization (Normalization)  (None, 14)           29          ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 14)           0           ['normalization[0][0]']
#
#  dense (Dense)                  (None, 15)           225         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 15)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 10)           160         ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 10)           0           ['dense_1[0][0]']
#
#  log_sigma_z_unit (Dense)       (None, 1)            11          ['dropout_2[0][0]']
#
#  mu_z_unit (Dense)              (None, 1)            11          ['dropout_2[0][0]']
#
#  log_sigma_unit (Rescaling)     (None, 1)            0           ['log_sigma_z_unit[0][0]']
#
#  mu_unit (Rescaling)            (None, 1)            0           ['mu_z_unit[0][0]']
#
#  sigma_unit (Exponentiate)      (None, 1)            0           ['log_sigma_unit[0][0]']
#
#  gamma_unit (Dense)             (None, 1)            11          ['dropout_2[0][0]']
#
#  concatenate (Concatenate)      (None, 3)            0           ['mu_unit[0][0]',
#                                                                   'sigma_unit[0][0]',
#                                                                   'gamma_unit[0][0]']
#
# ==================================================================================================
# Total params: 447
# Trainable params: 418
# Non-trainable params: 29
# __________________________________________________________________________________________________
# Restoring model weights from the end of the best epoch: 583.
# Epoch 00833: early stopping
# {'best_epoch': 582,
#  'elapsed_time': 20.11070728302002,
#  'loss_train': 5.553788661956787,
#  'loss_valid': 5.600208282470703,
#  'network_seed': 739}

# %%
2+2
# Out:
# 4
