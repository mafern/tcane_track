# %% [markdown]
# # Comparing methods of hurricane forecast uncertainty
# ##### author: Elizabeth A. Barnes, Randal J. Barnes and Mark DeMaria

# %%
import datetime
import os
import pickle
import pprint
import time

import experiment_settings
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from build_data import build_hurricane_data
import build_model
from model_diagnostics import plot_history
from save_model_run import save_model_run
from sklearn import preprocessing
from training_instrumentation import TrainingInstrumentation
from silence_tensorflow import silence_tensorflow
import tensorflow_probability as tfp
import random
import imp

silence_tensorflow()

tf.config.set_visible_devices([], 'GPU') # turn-off tensorflow-metal

# %%
__author__ = "Randal J Barnes and Elizabeth A. Barnes"
__version__ = "v1.0.1, 27 July 2022"

imp.reload(experiment_settings)
EXP_NAME_LIST = (
                 "longitude202_AL48",    
                 )

OVERWRITE_MODEL = False
DATA_PATH = "data/"
MODEL_PATH = "saved_models/"

# %%
mpl.rcParams["figure.facecolor"] = "white"
mpl.rcParams["figure.dpi"] = 150
np.warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %% [markdown]
# ## Start looping through runs

# %%
imp.reload(build_model)

for exp_name in EXP_NAME_LIST:
    settings = experiment_settings.get_settings(exp_name)

    # set testing data
    if settings["test_condition"] == "leave-one-out":
        TESTING_YEARS_LIST = np.arange(2013,2022)
    elif settings["test_condition"] == "years":
        TESTING_YEARS_LIST = (np.copy(settings["years_test"]))
    else:
        raise NotImplementError('no such testing condition')

        
        
    for testing_years in TESTING_YEARS_LIST:        
        # set testing year
        settings["years_test"] = (testing_years,)
        
        
        for rng_seed in settings['rng_seed_list']:
            settings['rng_seed'] = rng_seed

            # build the intensity data tensors
            (
                data_summary,        
                x_train,
                onehot_train,
                x_val,
                onehot_val,
                x_test,
                onehot_test,        
                x_valtest,
                onehot_valtest,
                df_train,
                df_val,
                df_test,
                df_valtest,
            ) = build_hurricane_data(DATA_PATH, settings, verbose=1)

            # define the callbacks
            earlystoping_callback = tf.keras.callbacks.EarlyStopping(
                monitor="val_loss",
                mode="min",
                patience=settings["patience"],
                restore_best_weights=True,
                verbose=1,
            )

            training_callback = TrainingInstrumentation(
                x_train,
                onehot_train,
                interval=50,
            )

            callbacks = [earlystoping_callback, 
                         # training_callback,
                        ]

            # set network seed and train the model
            NETWORK_SEED_LIST = [settings["rng_seed"]]

            for network_seed in NETWORK_SEED_LIST:
                
                # set random seeds
                np.random.seed(rng_seed)
                random.seed(rng_seed)                            
                tf.random.set_seed(network_seed) 

                # Create the model name.
                model_name = (
                    exp_name + "_" + 
                    str(testing_years) + '_' +
                    settings["uncertainty_type"] + '_' + 
                    f"network_seed_{network_seed}_rng_seed_{settings['rng_seed']}"
                )
                pprint.pprint(model_name)

                # Make, compile, and train the model
                tf.keras.backend.clear_session()            
                model = build_model.make_model(
                    settings,
                    x_train,
                    onehot_train,
                    model_compile=True,
                )   
                model.summary()

                # check if the model exists
                model_savename = MODEL_PATH + model_name + "_weights.h5"
                if os.path.exists(model_savename) and OVERWRITE_MODEL==False:
                    print(model_savename + 'exists. Skipping...')
                    continue

                # train the network
                start_time = time.time()
                history = model.fit(
                    x_train,
                    onehot_train,
                    validation_data=(x_val, onehot_val),
                    batch_size=settings["batch_size"],
                    epochs=settings["n_epochs"],
                    shuffle=True,
                    verbose=0,
                    callbacks=callbacks,
                )
                stop_time = time.time()

                # Display the results, and save the model rum.
                best_epoch = np.argmin(history.history["val_loss"])
                fit_summary = {
                    "network_seed": network_seed,
                    "elapsed_time": stop_time - start_time,
                    "best_epoch": best_epoch,
                    "loss_train": history.history["loss"][best_epoch],
                    "loss_valid": history.history["val_loss"][best_epoch],
                }
                pprint.pprint(fit_summary, width=80)
                plot_history(history, model_name)

                save_model_run(
                    data_summary,
                    fit_summary,
                    model,
                    MODEL_PATH,
                    model_name,
                    settings,
                    __version__,
                )
# Out:
# years(2013,) withheld for testing
# {'datafile_path': 'data/nnfit_vlist_02-Jun-2022.dat',
#  'onehot_test_shape': (71, 3),
#  'onehot_train_shape': (1505, 3),
#  'onehot_val_shape': (200, 3),
#  'x_names': ['NCT',
#              'VMAX0',
#              'AVDX',
#              'EMDX',
#              'EGDX',
#              'HWDX',
#              'LONC',
#              'LATC',
#              'VMXC',
#              'DV12',
#              'SLAT',
#              'SHDC',
#              'SSTN',
#              'DTL'],
#  'x_test_shape': (71, 14),
#  'x_train_shape': (1505, 14),
#  'x_val_shape': (200, 14),
#  'y_name': ['OBDX']}
# 'longitude202_AL48_2013_shash3_network_seed_416_rng_seed_416'
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 14)]         0           []
#
#  normalization (Normalization)  (None, 14)           29          ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 14)           0           ['normalization[0][0]']
#
#  dense (Dense)                  (None, 15)           225         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 15)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 10)           160         ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 10)           0           ['dense_1[0][0]']
#
#  log_sigma_z_unit (Dense)       (None, 1)            11          ['dropout_2[0][0]']
#
#  mu_z_unit (Dense)              (None, 1)            11          ['dropout_2[0][0]']
#
#  log_sigma_unit (Rescaling)     (None, 1)            0           ['log_sigma_z_unit[0][0]']
#
#  mu_unit (Rescaling)            (None, 1)            0           ['mu_z_unit[0][0]']
#
#  sigma_unit (Exponentiate)      (None, 1)            0           ['log_sigma_unit[0][0]']
#
#  gamma_unit (Dense)             (None, 1)            11          ['dropout_2[0][0]']
#
#  concatenate (Concatenate)      (None, 3)            0           ['mu_unit[0][0]',
#                                                                   'sigma_unit[0][0]',
#                                                                   'gamma_unit[0][0]']
#
# ==================================================================================================
# Total params: 447
# Trainable params: 418
# Non-trainable params: 29
# __________________________________________________________________________________________________
# saved_models/longitude202_AL48_2013_shash3_network_seed_416_rng_seed_416_weights.h5exists. Skipping...
# /Users/eabarnes/GoogleDrive/WORK/RESEARCH/2022/hurricane_uqcomparisons/build_data.py:301: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_valtest = df_val.append(df_test)
# years(2014,) withheld for testing
# {'datafile_path': 'data/nnfit_vlist_02-Jun-2022.dat',
#  'onehot_test_shape': (83, 3),
#  'onehot_train_shape': (1493, 3),
#  'onehot_val_shape': (200, 3),
#  'x_names': ['NCT',
#              'VMAX0',
#              'AVDX',
#              'EMDX',
#              'EGDX',
#              'HWDX',
#              'LONC',
#              'LATC',
#              'VMXC',
#              'DV12',
#              'SLAT',
#              'SHDC',
#              'SSTN',
#              'DTL'],
#  'x_test_shape': (83, 14),
#  'x_train_shape': (1493, 14),
#  'x_val_shape': (200, 14),
#  'y_name': ['OBDX']}
# 'longitude202_AL48_2014_shash3_network_seed_416_rng_seed_416'
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 14)]         0           []
#
#  normalization (Normalization)  (None, 14)           29          ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 14)           0           ['normalization[0][0]']
#
#  dense (Dense)                  (None, 15)           225         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 15)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 10)           160         ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 10)           0           ['dense_1[0][0]']
#
#  log_sigma_z_unit (Dense)       (None, 1)            11          ['dropout_2[0][0]']
#
#  mu_z_unit (Dense)              (None, 1)            11          ['dropout_2[0][0]']
#
#  log_sigma_unit (Rescaling)     (None, 1)            0           ['log_sigma_z_unit[0][0]']
#
#  mu_unit (Rescaling)            (None, 1)            0           ['mu_z_unit[0][0]']
#
#  sigma_unit (Exponentiate)      (None, 1)            0           ['log_sigma_unit[0][0]']
#
#  gamma_unit (Dense)             (None, 1)            11          ['dropout_2[0][0]']
#
#  concatenate (Concatenate)      (None, 3)            0           ['mu_unit[0][0]',
#                                                                   'sigma_unit[0][0]',
#                                                                   'gamma_unit[0][0]']
#
# ==================================================================================================
# Total params: 447
# Trainable params: 418
# Non-trainable params: 29
# __________________________________________________________________________________________________
# saved_models/longitude202_AL48_2014_shash3_network_seed_416_rng_seed_416_weights.h5exists. Skipping...
# years(2015,) withheld for testing
# {'datafile_path': 'data/nnfit_vlist_02-Jun-2022.dat',
#  'onehot_test_shape': (126, 3),
#  'onehot_train_shape': (1450, 3),
#  'onehot_val_shape': (200, 3),
#  'x_names': ['NCT',
#              'VMAX0',
#              'AVDX',
#              'EMDX',
#              'EGDX',
#              'HWDX',
#              'LONC',
#              'LATC',
#              'VMXC',
#              'DV12',
#              'SLAT',
#              'SHDC',
#              'SSTN',
#              'DTL'],
#  'x_test_shape': (126, 14),
#  'x_train_shape': (1450, 14),
#  'x_val_shape': (200, 14),
#  'y_name': ['OBDX']}
# 'longitude202_AL48_2015_shash3_network_seed_416_rng_seed_416'
# /Users/eabarnes/GoogleDrive/WORK/RESEARCH/2022/hurricane_uqcomparisons/build_data.py:301: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_valtest = df_val.append(df_test)
# /Users/eabarnes/GoogleDrive/WORK/RESEARCH/2022/hurricane_uqcomparisons/build_data.py:301: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_valtest = df_val.append(df_test)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 14)]         0           []
#
#  normalization (Normalization)  (None, 14)           29          ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 14)           0           ['normalization[0][0]']
#
#  dense (Dense)                  (None, 15)           225         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 15)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 10)           160         ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 10)           0           ['dense_1[0][0]']
#
#  log_sigma_z_unit (Dense)       (None, 1)            11          ['dropout_2[0][0]']
#
#  mu_z_unit (Dense)              (None, 1)            11          ['dropout_2[0][0]']
#
#  log_sigma_unit (Rescaling)     (None, 1)            0           ['log_sigma_z_unit[0][0]']
#
#  mu_unit (Rescaling)            (None, 1)            0           ['mu_z_unit[0][0]']
#
#  sigma_unit (Exponentiate)      (None, 1)            0           ['log_sigma_unit[0][0]']
#
#  gamma_unit (Dense)             (None, 1)            11          ['dropout_2[0][0]']
#
#  concatenate (Concatenate)      (None, 3)            0           ['mu_unit[0][0]',
#                                                                   'sigma_unit[0][0]',
#                                                                   'gamma_unit[0][0]']
#
# ==================================================================================================
# Total params: 447
# Trainable params: 418
# Non-trainable params: 29
# __________________________________________________________________________________________________
# saved_models/longitude202_AL48_2015_shash3_network_seed_416_rng_seed_416_weights.h5exists. Skipping...
# years(2016,) withheld for testing
# {'datafile_path': 'data/nnfit_vlist_02-Jun-2022.dat',
#  'onehot_test_shape': (230, 3),
#  'onehot_train_shape': (1346, 3),
#  'onehot_val_shape': (200, 3),
#  'x_names': ['NCT',
#              'VMAX0',
#              'AVDX',
#              'EMDX',
#              'EGDX',
#              'HWDX',
#              'LONC',
#              'LATC',
#              'VMXC',
#              'DV12',
#              'SLAT',
#              'SHDC',
#              'SSTN',
#              'DTL'],
#  'x_test_shape': (230, 14),
#  'x_train_shape': (1346, 14),
#  'x_val_shape': (200, 14),
#  'y_name': ['OBDX']}
# 'longitude202_AL48_2016_shash3_network_seed_416_rng_seed_416'
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 14)]         0           []
#
#  normalization (Normalization)  (None, 14)           29          ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 14)           0           ['normalization[0][0]']
#
#  dense (Dense)                  (None, 15)           225         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 15)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 10)           160         ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 10)           0           ['dense_1[0][0]']
#
#  log_sigma_z_unit (Dense)       (None, 1)            11          ['dropout_2[0][0]']
#
#  mu_z_unit (Dense)              (None, 1)            11          ['dropout_2[0][0]']
#
#  log_sigma_unit (Rescaling)     (None, 1)            0           ['log_sigma_z_unit[0][0]']
#
#  mu_unit (Rescaling)            (None, 1)            0           ['mu_z_unit[0][0]']
#
#  sigma_unit (Exponentiate)      (None, 1)            0           ['log_sigma_unit[0][0]']
#
#  gamma_unit (Dense)             (None, 1)            11          ['dropout_2[0][0]']
#
#  concatenate (Concatenate)      (None, 3)            0           ['mu_unit[0][0]',
#                                                                   'sigma_unit[0][0]',
#                                                                   'gamma_unit[0][0]']
#
# ==================================================================================================
# Total params: 447
# Trainable params: 418
# Non-trainable params: 29
# __________________________________________________________________________________________________
# saved_models/longitude202_AL48_2016_shash3_network_seed_416_rng_seed_416_weights.h5exists. Skipping...
# /Users/eabarnes/GoogleDrive/WORK/RESEARCH/2022/hurricane_uqcomparisons/build_data.py:301: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_valtest = df_val.append(df_test)
# /Users/eabarnes/GoogleDrive/WORK/RESEARCH/2022/hurricane_uqcomparisons/build_data.py:301: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_valtest = df_val.append(df_test)
# years(2017,) withheld for testing
# {'datafile_path': 'data/nnfit_vlist_02-Jun-2022.dat',
#  'onehot_test_shape': (260, 3),
#  'onehot_train_shape': (1316, 3),
#  'onehot_val_shape': (200, 3),
#  'x_names': ['NCT',
#              'VMAX0',
#              'AVDX',
#              'EMDX',
#              'EGDX',
#              'HWDX',
#              'LONC',
#              'LATC',
#              'VMXC',
#              'DV12',
#              'SLAT',
#              'SHDC',
#              'SSTN',
#              'DTL'],
#  'x_test_shape': (260, 14),
#  'x_train_shape': (1316, 14),
#  'x_val_shape': (200, 14),
#  'y_name': ['OBDX']}
# 'longitude202_AL48_2017_shash3_network_seed_416_rng_seed_416'
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 14)]         0           []
#
#  normalization (Normalization)  (None, 14)           29          ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 14)           0           ['normalization[0][0]']
#
#  dense (Dense)                  (None, 15)           225         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 15)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 10)           160         ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 10)           0           ['dense_1[0][0]']
#
#  log_sigma_z_unit (Dense)       (None, 1)            11          ['dropout_2[0][0]']
#
#  mu_z_unit (Dense)              (None, 1)            11          ['dropout_2[0][0]']
#
#  log_sigma_unit (Rescaling)     (None, 1)            0           ['log_sigma_z_unit[0][0]']
#
#  mu_unit (Rescaling)            (None, 1)            0           ['mu_z_unit[0][0]']
#
#  sigma_unit (Exponentiate)      (None, 1)            0           ['log_sigma_unit[0][0]']
#
#  gamma_unit (Dense)             (None, 1)            11          ['dropout_2[0][0]']
#
#  concatenate (Concatenate)      (None, 3)            0           ['mu_unit[0][0]',
#                                                                   'sigma_unit[0][0]',
#                                                                   'gamma_unit[0][0]']
#
# ==================================================================================================
# Total params: 447
# Trainable params: 418
# Non-trainable params: 29
# __________________________________________________________________________________________________
# saved_models/longitude202_AL48_2017_shash3_network_seed_416_rng_seed_416_weights.h5exists. Skipping...
# years(2018,) withheld for testing
# {'datafile_path': 'data/nnfit_vlist_02-Jun-2022.dat',
#  'onehot_test_shape': (243, 3),
#  'onehot_train_shape': (1333, 3),
#  'onehot_val_shape': (200, 3),
#  'x_names': ['NCT',
#              'VMAX0',
#              'AVDX',
#              'EMDX',
#              'EGDX',
#              'HWDX',
#              'LONC',
#              'LATC',
#              'VMXC',
#              'DV12',
#              'SLAT',
#              'SHDC',
#              'SSTN',
#              'DTL'],
#  'x_test_shape': (243, 14),
#  'x_train_shape': (1333, 14),
#  'x_val_shape': (200, 14),
#  'y_name': ['OBDX']}
# 'longitude202_AL48_2018_shash3_network_seed_416_rng_seed_416'
# /Users/eabarnes/GoogleDrive/WORK/RESEARCH/2022/hurricane_uqcomparisons/build_data.py:301: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_valtest = df_val.append(df_test)
# /Users/eabarnes/GoogleDrive/WORK/RESEARCH/2022/hurricane_uqcomparisons/build_data.py:301: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_valtest = df_val.append(df_test)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 14)]         0           []
#
#  normalization (Normalization)  (None, 14)           29          ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 14)           0           ['normalization[0][0]']
#
#  dense (Dense)                  (None, 15)           225         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 15)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 10)           160         ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 10)           0           ['dense_1[0][0]']
#
#  log_sigma_z_unit (Dense)       (None, 1)            11          ['dropout_2[0][0]']
#
#  mu_z_unit (Dense)              (None, 1)            11          ['dropout_2[0][0]']
#
#  log_sigma_unit (Rescaling)     (None, 1)            0           ['log_sigma_z_unit[0][0]']
#
#  mu_unit (Rescaling)            (None, 1)            0           ['mu_z_unit[0][0]']
#
#  sigma_unit (Exponentiate)      (None, 1)            0           ['log_sigma_unit[0][0]']
#
#  gamma_unit (Dense)             (None, 1)            11          ['dropout_2[0][0]']
#
#  concatenate (Concatenate)      (None, 3)            0           ['mu_unit[0][0]',
#                                                                   'sigma_unit[0][0]',
#                                                                   'gamma_unit[0][0]']
#
# ==================================================================================================
# Total params: 447
# Trainable params: 418
# Non-trainable params: 29
# __________________________________________________________________________________________________
# saved_models/longitude202_AL48_2018_shash3_network_seed_416_rng_seed_416_weights.h5exists. Skipping...
# years(2019,) withheld for testing
# {'datafile_path': 'data/nnfit_vlist_02-Jun-2022.dat',
#  'onehot_test_shape': (175, 3),
#  'onehot_train_shape': (1401, 3),
#  'onehot_val_shape': (200, 3),
#  'x_names': ['NCT',
#              'VMAX0',
#              'AVDX',
#              'EMDX',
#              'EGDX',
#              'HWDX',
#              'LONC',
#              'LATC',
#              'VMXC',
#              'DV12',
#              'SLAT',
#              'SHDC',
#              'SSTN',
#              'DTL'],
#  'x_test_shape': (175, 14),
#  'x_train_shape': (1401, 14),
#  'x_val_shape': (200, 14),
#  'y_name': ['OBDX']}
# 'longitude202_AL48_2019_shash3_network_seed_416_rng_seed_416'
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 14)]         0           []
#
#  normalization (Normalization)  (None, 14)           29          ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 14)           0           ['normalization[0][0]']
#
#  dense (Dense)                  (None, 15)           225         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 15)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 10)           160         ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 10)           0           ['dense_1[0][0]']
#
#  log_sigma_z_unit (Dense)       (None, 1)            11          ['dropout_2[0][0]']
#
#  mu_z_unit (Dense)              (None, 1)            11          ['dropout_2[0][0]']
#
#  log_sigma_unit (Rescaling)     (None, 1)            0           ['log_sigma_z_unit[0][0]']
#
#  mu_unit (Rescaling)            (None, 1)            0           ['mu_z_unit[0][0]']
#
#  sigma_unit (Exponentiate)      (None, 1)            0           ['log_sigma_unit[0][0]']
#
#  gamma_unit (Dense)             (None, 1)            11          ['dropout_2[0][0]']
#
#  concatenate (Concatenate)      (None, 3)            0           ['mu_unit[0][0]',
#                                                                   'sigma_unit[0][0]',
#                                                                   'gamma_unit[0][0]']
#
# ==================================================================================================
# Total params: 447
# Trainable params: 418
# Non-trainable params: 29
# __________________________________________________________________________________________________
# saved_models/longitude202_AL48_2019_shash3_network_seed_416_rng_seed_416_weights.h5exists. Skipping...
# years(2020,) withheld for testing
# {'datafile_path': 'data/nnfit_vlist_02-Jun-2022.dat',
#  'onehot_test_shape': (344, 3),
#  'onehot_train_shape': (1232, 3),
#  'onehot_val_shape': (200, 3),
#  'x_names': ['NCT',
#              'VMAX0',
#              'AVDX',
#              'EMDX',
#              'EGDX',
#              'HWDX',
#              'LONC',
#              'LATC',
#              'VMXC',
#              'DV12',
#              'SLAT',
#              'SHDC',
#              'SSTN',
#              'DTL'],
#  'x_test_shape': (344, 14),
#  'x_train_shape': (1232, 14),
#  'x_val_shape': (200, 14),
#  'y_name': ['OBDX']}
# 'longitude202_AL48_2020_shash3_network_seed_416_rng_seed_416'
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 14)]         0           []
#
#  normalization (Normalization)  (None, 14)           29          ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 14)           0           ['normalization[0][0]']
#
#  dense (Dense)                  (None, 15)           225         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 15)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 10)           160         ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 10)           0           ['dense_1[0][0]']
#
#  log_sigma_z_unit (Dense)       (None, 1)            11          ['dropout_2[0][0]']
#
#  mu_z_unit (Dense)              (None, 1)            11          ['dropout_2[0][0]']
#
#  log_sigma_unit (Rescaling)     (None, 1)            0           ['log_sigma_z_unit[0][0]']
#
#  mu_unit (Rescaling)            (None, 1)            0           ['mu_z_unit[0][0]']
#
#  sigma_unit (Exponentiate)      (None, 1)            0           ['log_sigma_unit[0][0]']
#
#  gamma_unit (Dense)             (None, 1)            11          ['dropout_2[0][0]']
#
#  concatenate (Concatenate)      (None, 3)            0           ['mu_unit[0][0]',
#                                                                   'sigma_unit[0][0]',
#                                                                   'gamma_unit[0][0]']
#
# ==================================================================================================
# Total params: 447
# Trainable params: 418
# Non-trainable params: 29
# __________________________________________________________________________________________________
# saved_models/longitude202_AL48_2020_shash3_network_seed_416_rng_seed_416_weights.h5exists. Skipping...
# years(2021,) withheld for testing
# {'datafile_path': 'data/nnfit_vlist_02-Jun-2022.dat',
#  'onehot_test_shape': (244, 3),
#  'onehot_train_shape': (1332, 3),
#  'onehot_val_shape': (200, 3),
#  'x_names': ['NCT',
#              'VMAX0',
#              'AVDX',
#              'EMDX',
#              'EGDX',
#              'HWDX',
#              'LONC',
#              'LATC',
#              'VMXC',
#              'DV12',
#              'SLAT',
#              'SHDC',
#              'SSTN',
#              'DTL'],
#  'x_test_shape': (244, 14),
#  'x_train_shape': (1332, 14),
#  'x_val_shape': (200, 14),
#  'y_name': ['OBDX']}
# 'longitude202_AL48_2021_shash3_network_seed_416_rng_seed_416'
# /Users/eabarnes/GoogleDrive/WORK/RESEARCH/2022/hurricane_uqcomparisons/build_data.py:301: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_valtest = df_val.append(df_test)
# /Users/eabarnes/GoogleDrive/WORK/RESEARCH/2022/hurricane_uqcomparisons/build_data.py:301: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_valtest = df_val.append(df_test)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 14)]         0           []
#
#  normalization (Normalization)  (None, 14)           29          ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 14)           0           ['normalization[0][0]']
#
#  dense (Dense)                  (None, 15)           225         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 15)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 10)           160         ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 10)           0           ['dense_1[0][0]']
#
#  log_sigma_z_unit (Dense)       (None, 1)            11          ['dropout_2[0][0]']
#
#  mu_z_unit (Dense)              (None, 1)            11          ['dropout_2[0][0]']
#
#  log_sigma_unit (Rescaling)     (None, 1)            0           ['log_sigma_z_unit[0][0]']
#
#  mu_unit (Rescaling)            (None, 1)            0           ['mu_z_unit[0][0]']
#
#  sigma_unit (Exponentiate)      (None, 1)            0           ['log_sigma_unit[0][0]']
#
#  gamma_unit (Dense)             (None, 1)            11          ['dropout_2[0][0]']
#
#  concatenate (Concatenate)      (None, 3)            0           ['mu_unit[0][0]',
#                                                                   'sigma_unit[0][0]',
#                                                                   'gamma_unit[0][0]']
#
# ==================================================================================================
# Total params: 447
# Trainable params: 418
# Non-trainable params: 29
# __________________________________________________________________________________________________
# Restoring model weights from the end of the best epoch: 1423.
# Epoch 01673: early stopping
# {'best_epoch': 1422,
#  'elapsed_time': 33.07419228553772,
#  'loss_train': 5.6130523681640625,
#  'loss_valid': 5.821432113647461,
#  'network_seed': 416}

# %%
2+2
# Out:
# 4
