# %%
import mahalanobis

# %%
mu_u = 1.0
mu_v = 1.0
sigma_u = 2.0
sigma_v = 1.0
rho = 0.5

mahalanobis.plot_cdf(mu_u, mu_v, sigma_u, sigma_v, rho)

# %%
print(mahalanobis.compute_cdf(mu_u, mu_v, sigma_u, sigma_v, rho, u=2.0, v=2.0))
# Out:
# 0.15351827510938587
